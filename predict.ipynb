# %%
from ultralytics import YOLO

yolo = YOLO("./yolov8n.pt", task="detect")

result = yolo(source="./ultralytics/assets/bus.jpg")
# Out:
# 代码注入！！！
#
#
# image 1/1 /home/friver/ultralytics-main/ultralytics/assets/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 51.9ms
# Speed: 3.9ms preprocess, 51.9ms inference, 18.1ms postprocess per image at shape (1, 3, 640, 480)
